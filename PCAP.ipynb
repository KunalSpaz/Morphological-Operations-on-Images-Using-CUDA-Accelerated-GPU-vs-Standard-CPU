# %%
! nvidia-smi
# Out:
# Wed Apr  9 14:37:48 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load and display the image
img = Image.open('image.pgm')
plt.imshow(img, cmap='gray')
plt.title("Input PGM Image")
plt.axis('off')
plt.show()

# %%
# !nvcc -gencode arch=compute_75,code=sm_75 -o PCAPProject PCAPProject.cu

# %%
! ./PCAPProject
# Out:
# Sample INPUT pixel values:
# 90 93 99 104 105 105 103 101 95 97
# Sample DILATED pixel values:
# 94 99 104 105 109 113 114 114 114 111
# Sample ERODED pixel values:
# 90 90 93 96 100 103 101 95 95 95
# Done.

# %%
from PIL import Image
import matplotlib.pyplot as plt

img_dil = Image.open("dilated.pgm")
img_ero = Image.open("eroded.pgm")

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.imshow(img_dil, cmap='gray')
plt.title("Dilation")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_ero, cmap='gray')
plt.title("Erosion")
plt.axis('off')

plt.show()
